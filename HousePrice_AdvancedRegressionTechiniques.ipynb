# %%
# Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 50)

# %%
# Get Data
train = pd.read_csv("./data/train.csv")
test = pd.read_csv("./data/test.csv")
sample_submission = pd.read_csv("./data/sample_submission.csv")

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_cat = train.select_dtypes(include='object')
cat_cols = train_cat.columns

# %%
train_cat.describe(include='object')
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1460         1460       1460       1460     1460       1460
# unique         3           25          9          8        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1382          225       1260       1445     1220        726
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1460     1460        1460        1460       1452      1460
# unique         6        8          15          16          4         4
# ...

# %%
train_num = train.select_dtypes(exclude='object')
num_cols = train_num.columns

# %%
train_num
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ### Missing Values

# %%
plt.figure(figsize=(20,10))
sns.heatmap(train.isnull(), yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
train_nan = train.isnull().sum() / len(train) * 100
train_nan = train_nan.drop(train_nan[train_nan == 0].index).sort_values(ascending=False)
train_nan = pd.DataFrame({'MissingData': train_nan})

# %%
train_nan
# Out:
#               MissingData
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# BsmtExposure     2.602740
# BsmtFinType2     2.602740
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# BsmtQual         2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493

# %%
train_nan_cat = [col for col in train_nan.index if col in cat_cols]
train_nan_cat
# Out:
# ['PoolQC',
#  'MiscFeature',
#  'Alley',
#  'Fence',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'BsmtExposure',
#  'BsmtFinType2',
#  'BsmtFinType1',
#  'BsmtCond',
#  'BsmtQual',
#  'MasVnrType',
#  'Electrical']

# %%
train_filled_cat = [col for col in cat_cols if col not in train_nan.index]
train_filled_cat
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
train_nan_num = [col for col in train_nan.index if col in num_cols]
train_nan_num
# Out:
# ['LotFrontage', 'GarageYrBlt', 'MasVnrArea']

# %%
train_filled_num = [col for col in num_cols if col not in train_nan.index]
train_filled_num
# Out:
# ['Id',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %% [markdown]
# ###### Test Columns

# %%
test_nan_cat = [col for col in test_nan.index if col in cat_cols]
test_nan_cat
# Out:
# ['PoolQC',
#  'MiscFeature',
#  'Alley',
#  'Fence',
#  'FireplaceQu',
#  'GarageCond',
#  'GarageQual',
#  'GarageFinish',
#  'GarageType',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtQual',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'MasVnrType',
#  'MSZoning',
#  'Functional',
#  'Utilities',
#  'KitchenQual',
#  'Exterior2nd',
#  'Exterior1st',
#  'SaleType']

# %%
test_filled_cat = [col for col in cat_cols if col not in test_nan.index]
test_filled_cat
# Out:
# ['Street',
#  'LotShape',
#  'LandContour',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'PavedDrive',
#  'SaleCondition']

# %%
test_nan_num = [col for col in test_nan.index if col in num_cols]
test_nan_num
# Out:
# ['LotFrontage',
#  'GarageYrBlt',
#  'MasVnrArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageCars',
#  'GarageArea',
#  'TotalBsmtSF',
#  'BsmtUnfSF',
#  'BsmtFinSF2',
#  'BsmtFinSF1']

# %%
test_filled_num = [col for col in num_cols if col not in test_nan.index]
test_filled_num
# Out:
# ['Id',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
plt.figure(figsize=(20,10))
sns.heatmap(test.isnull(), yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
test_nan = test.isnull().sum() / len(test) * 100
test_nan = test_nan.drop(test_nan[test_nan == 0].index).sort_values(ascending=False)
test_nan = pd.DataFrame({'MissingData': test_nan})

# %%
test_nan
# Out:
#               MissingData
# PoolQC          99.794380
# MiscFeature     96.504455
# Alley           92.666210
# Fence           80.123372
# FireplaceQu     50.034270
# LotFrontage     15.558602
# GarageCond       5.346127
# GarageYrBlt      5.346127
# GarageQual       5.346127
# GarageFinish     5.346127
# GarageType       5.209047
# BsmtCond         3.084304
# BsmtExposure     3.015764
# BsmtQual         3.015764
# BsmtFinType1     2.878684
# BsmtFinType2     2.878684
# MasVnrType       1.096642
# MasVnrArea       1.028101
# MSZoning         0.274160
# BsmtFullBath     0.137080
# BsmtHalfBath     0.137080
# Functional       0.137080
# Utilities        0.137080
# GarageCars       0.068540
# GarageArea       0.068540
# TotalBsmtSF      0.068540
# KitchenQual      0.068540
# BsmtUnfSF        0.068540
# BsmtFinSF2       0.068540
# BsmtFinSF1       0.068540
# Exterior2nd      0.068540
# Exterior1st      0.068540
# SaleType         0.068540

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='Fence', data=train)
# Out:
# <AxesSubplot:xlabel='Fence', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='Alley', data=train)
# Out:
# <AxesSubplot:xlabel='Alley', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.histplot(x='Neighborhood', data=train)
plt.xticks(rotation=70)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.histplot(x='Neighborhood', y='LotFrontage', data=train)
plt.xticks(rotation=70)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='Neighborhood', y='LotFrontage', data=train)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ### Outliers
